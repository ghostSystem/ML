# %%
import pandas as pd
import numpy as np

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7ed0097d7e9e> in <module>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
pwd
# Out:
# '/Users/astitvnagpal/Ghost_Files/Udemy_Courses/MachineLearning_Python/Python-Data-Science-and-Machine-Learning-Bootcamp/Python-for-Data-Analysis/Pandas'

# %%
pd.read_csv('example')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df=pd.read_csv('example')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv('My_Output', index=False)

# %%
pd.read_csv('My_Output')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
pd.read_excel('Excel_Sample.xlsx', sheet_name='Sheet1')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_excel('Excel_Sample2.xlsx', sheet_name='NewSheet')

# %%
data = pd.read_html('https://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
type(data)
# Out:
# list

# %%
data[0].head()
# Out:
#                                            Bank Name         City  ST   CERT  \
# 0                Washington Federal Bank for Savings      Chicago  IL  30570
# 1    The Farmers and Merchants State Bank of Argonia      Argonia  KS  17719
# 2                                Fayette County Bank   Saint Elmo  IL   1802
# 3  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...    Milwaukee  WI  30003
# 4                                     First NBC Bank  New Orleans  LA  58302
#
#                  Acquiring Institution       Closing Date       Updated Date
# 0                   Royal Savings Bank  December 15, 2017  December 20, 2017
# 1                          Conway Bank   October 13, 2017   October 20, 2017
# 2            United Fidelity Bank, fsb       May 26, 2017      July 26, 2017
# 3  First-Citizens Bank & Trust Company        May 5, 2017      July 26, 2017
# 4                         Whitney Bank     April 28, 2017   December 5, 2017

# %%
data
# Out:
# [                                             Bank Name                City  \
#  0                  Washington Federal Bank for Savings             Chicago
#  1      The Farmers and Merchants State Bank of Argonia             Argonia
#  2                                  Fayette County Bank          Saint Elmo
#  3    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
#  4                                       First NBC Bank         New Orleans
#  5                                        Proficio Bank  Cottonwood Heights
#  6                        Seaway Bank and Trust Company             Chicago
#  7                               Harvest Community Bank          Pennsville
#  8                                          Allied Bank            Mulberry
#  9                         The Woodbury Banking Company            Woodbury
#  10                              First CornerStone Bank     King of Prussia
# ...

# %%
data[0]
# Out:
#                                              Bank Name                City  \
# 0                  Washington Federal Bank for Savings             Chicago
# 1      The Farmers and Merchants State Bank of Argonia             Argonia
# 2                                  Fayette County Bank          Saint Elmo
# 3    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 4                                       First NBC Bank         New Orleans
# 5                                        Proficio Bank  Cottonwood Heights
# 6                        Seaway Bank and Trust Company             Chicago
# 7                               Harvest Community Bank          Pennsville
# 8                                          Allied Bank            Mulberry
# 9                         The Woodbury Banking Company            Woodbury
# 10                              First CornerStone Bank     King of Prussia
# ...

# %%
data[0]
# Out:
#                                              Bank Name                City  \
# 0                  Washington Federal Bank for Savings             Chicago
# 1      The Farmers and Merchants State Bank of Argonia             Argonia
# 2                                  Fayette County Bank          Saint Elmo
# 3    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 4                                       First NBC Bank         New Orleans
# 5                                        Proficio Bank  Cottonwood Heights
# 6                        Seaway Bank and Trust Company             Chicago
# 7                               Harvest Community Bank          Pennsville
# 8                                          Allied Bank            Mulberry
# 9                         The Woodbury Banking Company            Woodbury
# 10                              First CornerStone Bank     King of Prussia
# ...

# %%
data = pd.read_html('http://www.msinus.com/content/computer-science-rankings-us-universities-265/')

# %%
data[0]
# Out:
#      0                                     1                2
# 0    1                                   MIT        CAMBRIDGE
# 1    2                   Stanford University         STANFORD
# 2    3     University Of California-Berkeley         BERKELEY
# 3    4            Carnegie Mellon University       PITTSBURGH
# 4    5                    Cornell University           ITHACA
# 5    6                  Princeton University        PRINCETON
# 6    7       California Institute Technology         PASADENA
# 7    8         University Of Texas At Austin           AUSTIN
# 8    9                    Harvard University        CAMBRIDGE
# 9   10  Univ Of Illinois At Urbana,Champaign           URBANA
# 10  11       University Of Wisconsin-Madison          MADISON
# 11  12        Univ Of California,Los Angeles      Los Angeles
# 12  13                       Yale University        New Haven
# 13  14   University Of Maryland College Park     College Park
# ...

# %%
data[0].loc[0]
# Out:
# 0            1
# 1          MIT
# 2    CAMBRIDGE
# Name: 0, dtype: object

# %%
from sqlalchemy import create_engine as ce

# %%
engine  = ce('sqlite:///:memory:')

# %%
df.to_sql('myTable_sql', engine)

# %%
sqldf = pd.read_sql('myTable_sql', con=engine)

# %%
sqldf
# Out:
#    index   a   b   c   d
# 0      0   0   1   2   3
# 1      1   4   5   6   7
# 2      2   8   9  10  11
# 3      3  12  13  14  15

# %%
df_con = pd.read_html('https://www.natureindex.com/annual-tables/2016/country/all')

# %%
df_con[0]
# Out:
#     2015                  Country/Region  WFC 2014  WFC 2015  AC 2015  \
# 0      1  United States of America (USA)  18023.54  17232.78    26695
# 1      2                           China   6187.01   6501.88     9698
# 2      3                         Germany   4056.38   4092.86     9168
# 3      4             United Kingdom (UK)   3280.33   3376.44     8394
# 4      5                           Japan   3223.87   3063.71     5049
# 5      6                          France   2237.85   2133.28     5495
# 6      7                          Canada   1501.35   1477.92     3319
# 7      8                     Switzerland   1297.50   1137.15     2959
# 8      9                     South Korea   1182.88   1116.40     2069
# 9     10                           Italy   1055.04   1068.52     3428
# 10    11                           Spain   1098.63   1059.37     3228
# 11    12                       Australia    958.62    942.75     2686
# ...

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('MS in US FALL 17 Results.xlsx', sheet_name='Form Responses 1')

# %%
df.head()
# Out:
#                     Timestamp               Applied University Name  \
# 0  2017-02-07 14:51:44.238000                                   USC
# 1  2017-03-31 22:40:13.369000  University of California Los Angeles
# 2  2017-03-31 22:41:11.203000    University of California San Diego
# 3  2017-03-31 22:42:11.613000         University of Texas at Austin
# 4  2017-03-31 22:43:11.437000   University of Massachusetts Amherst
#
#   Applied Branch Decision    Acads      UG University GRE Total GRE Quant  \
# 0          MS CS    Admit   9.8/10               BITS       334       170
# 1             CS    Admit  9.45/10  Thapar University       330       168
# 2             CS    Admit  9.45/10  Thapar University       330       168
# 3             CS    Admit  9.45/10  Thapar University       330       168
# 4             CS    Admit  9.45/10  Thapar University       330       168
#
#   GRE Verbal             TOEFL     ...     UG Branch  \
# 0        164  117(27:30:28:30)     ...            CS
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'Applied University Name', 'Applied Branch', 'Decision',
#        'Acads', 'UG University', 'GRE Total', 'GRE Quant', 'GRE Verbal',
#        'TOEFL', 'IELTS', 'Work Ex', 'UG Branch', 'Category (your assumption)',
#        'Application Date', 'Decision Date', 'Your name (Optional)',
#        'Your mail ID (Optional)', 'Email Address', 'Paper Published ',
#        'Outstanding achievements ', 'Unnamed: 21'],
#       dtype='object')

# %%
df=df[['Applied University Name','Applied Branch', 'Decision', 'Acads', 'GRE Total', 'GRE Quant','GRE Verbal', 'TOEFL','Work Ex','Application Date','Decision Date']]

# %%
df.head()
# Out:
#                 Applied University Name Applied Branch Decision    Acads  \
# 0                                   USC          MS CS    Admit   9.8/10
# 1  University of California Los Angeles             CS    Admit  9.45/10
# 2    University of California San Diego             CS    Admit  9.45/10
# 3         University of Texas at Austin             CS    Admit  9.45/10
# 4   University of Massachusetts Amherst             CS    Admit  9.45/10
#
#   GRE Total GRE Quant GRE Verbal             TOEFL   Work Ex Application Date  \
# 0       334       170        164  117(27:30:28:30)         0            23/11
# 1       330       168        162               109  4 months              NaN
# 2       330       168        162               109  4 months              NaN
# 3       330       168        162               109  4 months              NaN
# 4       330       168        162               109  4 months              NaN
#
#   Decision Date
# 0          20/1
# 1           NaN
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as mlt

# %%
# %matplotlib inline

# %%
df
# Out:
#                          Applied University Name       Applied Branch  \
# 0                                            USC                MS CS
# 1           University of California Los Angeles                   CS
# 2             University of California San Diego                   CS
# 3                  University of Texas at Austin                   CS
# 4            University of Massachusetts Amherst                   CS
# 5               University of California, Irvine                   CS
# 6                                            UTD                   CE
# 7                                  UMass Amherst                   CE
# 8                                  UMass Amherst                   CS
# 9                                            USC                   CS
# 10                                           UTD                   CS
# 11                                   Iit chicago                 Mscs
# ...

# %%
df=df[['Applied University Name','Applied Branch', 'Decision', 'Acads', 'GRE Total', 'GRE Quant','GRE Verbal', 'TOEFL','Work Ex','Application Date','Decision Date']]

# %%
df.set_index('Applied University Name', inplace=True)

# %%
df
# Out:
#                          Applied University Name       Applied Branch  \
# 0                                            USC                MS CS
# 1           University of California Los Angeles                   CS
# 2             University of California San Diego                   CS
# 3                  University of Texas at Austin                   CS
# 4            University of Massachusetts Amherst                   CS
# 5               University of California, Irvine                   CS
# 6                                            UTD                   CE
# 7                                  UMass Amherst                   CE
# 8                                  UMass Amherst                   CS
# 9                                            USC                   CS
# 10                                           UTD                   CS
# 11                                   Iit chicago                 Mscs
# ...

# %%
df.loc['Arizona State University']
# Out:
#                          Applied Branch Decision     Acads GRE Total  \
# Applied University Name
# Arizona State University             CS    Admit   8.76/10       323
# Arizona State University             CS    Admit    8.3/10       331
# Arizona State University             IT    Admit    7.2/10       318
# Arizona State University             CS    Admit  3.59/4.0       316
# Arizona State University             CS    Admit      9.11       321
# Arizona State University             CS    Admit      9.03       325
# Arizona State University             CS    Admit      8.26       319
# Arizona State University           MISM    Admit         8       307
# Arizona State University             CS   Reject      7.77       311
# Arizona State University            MIS    Admit      7.27       315
#
#                          GRE Quant GRE Verbal             TOEFL Work Ex  \
# Applied University Name
# Arizona State University       166        157  108(27:26:26:29)      1Y
# ...

# %%
df[['Applied Branch','Acads']]
# Out:
#                                                   Applied Branch       Acads
# Applied University Name
# USC                                                        MS CS      9.8/10
# University of California Los Angeles                          CS     9.45/10
# University of California San Diego                            CS     9.45/10
# University of Texas at Austin                                 CS     9.45/10
# University of Massachusetts Amherst                           CS     9.45/10
# University of California, Irvine                              CS     9.42/10
# UTD                                                           CE     9.38/10
# UMass Amherst                                                 CE     9.38/10
# UMass Amherst                                                 CS      9.3/10
# USC                                                           CS     9.24/10
# UTD                                                           CS     9.15/10
# ...

# %%
df.loc['UTD']
# Out:
#                         Applied Branch Decision     Acads GRE Total GRE Quant  \
# Applied University Name
# UTD                                 CE    Admit   9.38/10       304       156
# UTD                                 CS    Admit   9.15/10       312       161
# UTD                                 CS    Admit   8.79/10       316       163
# UTD                              MS CS    Admit    8.5/10       311       158
# UTD                                 CE   Reject    8.3/10       315       162
# UTD                                 CS    Admit   8.29/10       319       167
# UTD                              MS CS    Admit    8.1/10       318       160
# UTD                                 CS    Admit   8.06/10       306       159
# UTD                                 CS   Reject  8..67/10       308       167
# UTD                                 CS   Reject   7.88/10       319       165
# UTD                                 CS    Admit    7.8/10       316       168
# ...

# %%
df.loc['UTD',['Acads','GRE Total','Decision']]
# Out:
#                             Acads GRE Total Decision
# Applied University Name
# UTD                       9.38/10       304    Admit
# UTD                       9.15/10       312    Admit
# UTD                       8.79/10       316    Admit
# UTD                        8.5/10       311    Admit
# UTD                        8.3/10       315   Reject
# UTD                       8.29/10       319    Admit
# UTD                        8.1/10       318    Admit
# UTD                       8.06/10       306    Admit
# UTD                      8..67/10       308   Reject
# UTD                       7.88/10       319   Reject
# UTD                        7.8/10       316    Admit
# UTD                       7.66/10       309   Reject
# UTD                        7.6/10       326    Admit
# UTD                       7.25/10       313    Admit
# UTD                      3.41/4.0       313    Admit
# UTD                       3.1/4.0       315   Reject
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                                   Applied Branch Decision  \
# Applied University Name
# USC                                                        MS CS    Admit
# University of California Los Angeles                          CS    Admit
# University of California San Diego                            CS    Admit
# University of Texas at Austin                                 CS    Admit
# University of Massachusetts Amherst                           CS    Admit
# University of California, Irvine                              CS    Admit
# UTD                                                           CE    Admit
# UMass Amherst                                                 CE    Admit
# UMass Amherst                                                 CS    Admit
# USC                                                           CS    Admit
# UTD                                                           CS    Admit
# ...

# %%
rows = df.count

# %%
len(df)
# Out:
# 252

# %%
df=pd.read_excel('MS in US FALL 17 Results.xlsx')

# %%
len(df)
# Out:
# 487

# %%
df.head()
# Out:
#                                     Timestamp  \
# 0  To add an entry to the sheet please go to:
# 1                  2016-12-07 19:43:51.909000
# 2                  2016-12-07 20:28:00.274000
# 3                  2016-12-07 20:40:01.732000
# 4                  2016-12-07 21:19:19.567000
#
#              Applied University Name  \
# 0         http://bit.ly/fall17MSform
# 1                                UTD
# 2                                UTD
# 3  Michigan technological University
# 4           Arizona State University
#
#                                     Applied Branch                 Decision  \
# 0  If you feel any entry is fake let me know at ->  srujanbarai75@gmail.com
# 1                                            MS CS                    Admit
# 2                                             Mech                    Admit
# 3                                    Data science                     Admit
# ...

# %%
df.set_index('Applied University Name', inplace=True)

# %%
df.head()
# Out:
#                                                                     Timestamp  \
# Applied University Name
# http://bit.ly/fall17MSform         To add an entry to the sheet please go to:
# UTD                                                2016-12-07 19:43:51.909000
# UTD                                                2016-12-07 20:28:00.274000
# Michigan technological University                  2016-12-07 20:40:01.732000
# Arizona State University                           2016-12-07 21:19:19.567000
#
#                                                                     Applied Branch  \
# Applied University Name
# http://bit.ly/fall17MSform         If you feel any entry is fake let me know at ->
# UTD                                                                          MS CS
# UTD                                                                           Mech
# Michigan technological University                                    Data science
# ...

# %%
del df['Timestamp']

# %%
df.head()
# Out:
#                                                                     Applied Branch  \
# Applied University Name
# http://bit.ly/fall17MSform         If you feel any entry is fake let me know at ->
# UTD                                                                          MS CS
# UTD                                                                           Mech
# Michigan technological University                                    Data science
# Arizona State University                                        Business Analytics
#
#                                                   Decision   Acads  \
# Applied University Name
# http://bit.ly/fall17MSform         srujanbarai75@gmail.com     NaN
# UTD                                                  Admit  7.6/10
# UTD                                                  Admit  7.5/10
# Michigan technological University                    Admit  6.6/10
# Arizona State University                             Admit    7.85
#
# ...

# %%
df.drop('http://bit.ly/fall17MSform', inplace=True)

# %%
df.head()
# Out:
#                                                                     Applied Branch  \
# Applied University Name
# http://bit.ly/fall17MSform         If you feel any entry is fake let me know at ->
# UTD                                                                          MS CS
# UTD                                                                           Mech
# Michigan technological University                                    Data science
# Arizona State University                                        Business Analytics
#
#                                                   Decision   Acads  \
# Applied University Name
# http://bit.ly/fall17MSform         srujanbarai75@gmail.com     NaN
# UTD                                                  Admit  7.6/10
# UTD                                                  Admit  7.5/10
# Michigan technological University                    Admit  6.6/10
# Arizona State University                             Admit    7.85
#
# ...

# %%
df.head()
# Out:
#                                        Applied Branch Decision   Acads  \
# Applied University Name
# UTD                                             MS CS    Admit  7.6/10
# UTD                                              Mech    Admit  7.5/10
# Michigan technological University       Data science     Admit  6.6/10
# Arizona State University           Business Analytics    Admit    7.85
# University of Texas Arlington                  Civil     Admit    7.52
#
#                                        UG University GRE Total GRE Quant  \
# Applied University Name
# UTD                                               MU       326       167
# UTD                                 Anna University        318       158
# Michigan technological University  GITAM University        303       154
# Arizona State University                          MU       307       161
# University of Texas Arlington       Kiit University        324       167
#
# ...

# %%
df.loc[['UTD'],['GRE Total','Decision']]
# Out:
#                         GRE Total Decision
# Applied University Name
# UTD                           326    Admit
# UTD                           318    Admit
# UTD                           311    Admit
# UTD                           308    Admit
# UTD                           318    Admit
# UTD                           304    Admit
# UTD                           321    Admit
# UTD                           309    Admit
# UTD                           316    Admit
# UTD                           319   Reject
# UTD                           298    Admit
# UTD                           318    Admit
# UTD                           308    Admit
# UTD                           315   Reject
# UTD                           302   Reject
# UTD                           302   Reject
# UTD                           309   Reject
# UTD                           305   Reject
# UTD                           306    Admit
# UTD                           304   Reject
# ...

# %%
df[(df['Decision']=='Admit') & (df['UG Branch']=='CE')]
# Out:
#                                                                            Applied Branch  \
# Applied University Name
# UTD                                                                                 MS CS
# University of Southern California                                                      CE
# Stevens institute of technology                    Construction engineering & management
# Santa Clara University                                                                CSE
# Carnegie Mellon university                                                             CE
# Stevens Institute of Technology                                                        CE
# University of Washington, Seattle                                                      CE
# UT Austin                                                                            ORIE
# Texas A&M                                                                              CE
# ...

# %%
df.index
# Out:
# Index(['UTD', 'UTD', 'Michigan technological University',
#        'Arizona State University', 'University of Texas Arlington', 'UTD',
#        'Wayne state university', 'Santa Clara University', 'UTD', 'UTD',
#        ...
#        'new jersey inst. of tech.', 'University of California Los Angeles',
#        'University of California San Diego', 'University of Texas at Austin',
#        'University of Massachusetts Amherst', 'UIC', 'ASU',
#        'University of Wisconsin, Madison', 'University of Southern California',
#        '-'],
#       dtype='object', name='Applied University Name', length=486)

# %%
df.set_index('Applied University Name')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Applied University Name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-110-6422d0c8cfc0> in <module>()
# ...

# %%
df=pd.read_excel('MS in US FALL 17 Results.xlsx')

# %%
df.head()
# Out:
#                                     Timestamp  \
# 0  To add an entry to the sheet please go to:
# 1                  2016-12-07 19:43:51.909000
# 2                  2016-12-07 20:28:00.274000
# 3                  2016-12-07 20:40:01.732000
# 4                  2016-12-07 21:19:19.567000
#
#              Applied University Name  \
# 0         http://bit.ly/fall17MSform
# 1                                UTD
# 2                                UTD
# 3  Michigan technological University
# 4           Arizona State University
#
#                                     Applied Branch                 Decision  \
# 0  If you feel any entry is fake let me know at ->  srujanbarai75@gmail.com
# 1                                            MS CS                    Admit
# 2                                             Mech                    Admit
# 3                                    Data science                     Admit
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=487, step=1)

# %%
df.drop('Timestamp', axis=1)
# Out:
#                   Applied University Name  \
# 0              http://bit.ly/fall17MSform
# 1                                     UTD
# 2                                     UTD
# 3       Michigan technological University
# 4                Arizona State University
# 5           University of Texas Arlington
# 6                                     UTD
# 7                  Wayne state university
# 8                  Santa Clara University
# 9                                     UTD
# 10                                    UTD
# 11                                    UTD
# 12                                    RIT
# 13                                   UNCC
# 14        Stevens institute of technology
# 15                                    UTD
# 16                           IIT Chicago
# 17                  Ohio State University
# 18                                    UTD
# 19            University of Texas Dallas
# 20                                    ASU
# ...

# %%
df.set_index('Applied University Name')
# Out:
#                                                                        Timestamp  \
# Applied University Name
# http://bit.ly/fall17MSform            To add an entry to the sheet please go to:
# UTD                                                   2016-12-07 19:43:51.909000
# UTD                                                   2016-12-07 20:28:00.274000
# Michigan technological University                     2016-12-07 20:40:01.732000
# Arizona State University                              2016-12-07 21:19:19.567000
# University of Texas Arlington                         2016-12-07 22:03:28.557000
# UTD                                                   2016-12-08 07:36:53.632000
# Wayne state university                                2016-12-08 08:11:29.092000
# Santa Clara University                                2016-12-08 19:36:27.937000
# UTD                                                   2016-12-08 19:38:55.935000
# ...

# %%
df.head()
# Out:
#                                     Timestamp  \
# 0  To add an entry to the sheet please go to:
# 1                  2016-12-07 19:43:51.909000
# 2                  2016-12-07 20:28:00.274000
# 3                  2016-12-07 20:40:01.732000
# 4                  2016-12-07 21:19:19.567000
#
#              Applied University Name  \
# 0         http://bit.ly/fall17MSform
# 1                                UTD
# 2                                UTD
# 3  Michigan technological University
# 4           Arizona State University
#
#                                     Applied Branch                 Decision  \
# 0  If you feel any entry is fake let me know at ->  srujanbarai75@gmail.com
# 1                                            MS CS                    Admit
# 2                                             Mech                    Admit
# 3                                    Data science                     Admit
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=487, step=1)

# %%
df2=df.copy()

# %%
df2.head()
# Out:
#                                     Timestamp  \
# 0  To add an entry to the sheet please go to:
# 1                  2016-12-07 19:43:51.909000
# 2                  2016-12-07 20:28:00.274000
# 3                  2016-12-07 20:40:01.732000
# 4                  2016-12-07 21:19:19.567000
#
#              Applied University Name  \
# 0         http://bit.ly/fall17MSform
# 1                                UTD
# 2                                UTD
# 3  Michigan technological University
# 4           Arizona State University
#
#                                     Applied Branch                 Decision  \
# 0  If you feel any entry is fake let me know at ->  srujanbarai75@gmail.com
# 1                                            MS CS                    Admit
# 2                                             Mech                    Admit
# 3                                    Data science                     Admit
# ...

# %%
df2.set_index('Applied University Name', inplace=True)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=487, step=1)

# %%
df2.index
# Out:
# Index(['http://bit.ly/fall17MSform', 'UTD', 'UTD',
#        'Michigan technological University', 'Arizona State University',
#        'University of Texas Arlington', 'UTD', 'Wayne state university',
#        'Santa Clara University', 'UTD',
#        ...
#        'new jersey inst. of tech.', 'University of California Los Angeles',
#        'University of California San Diego', 'University of Texas at Austin',
#        'University of Massachusetts Amherst', 'UIC', 'ASU',
#        'University of Wisconsin, Madison', 'University of Southern California',
#        '-'],
#       dtype='object', name='Applied University Name', length=487)

# %%
df[df['Applied University Name']=='UTD']
# Out:
#                       Timestamp Applied University Name  \
# 1    2016-12-07 19:43:51.909000                     UTD
# 2    2016-12-07 20:28:00.274000                     UTD
# 6    2016-12-08 07:36:53.632000                     UTD
# 9    2016-12-08 19:38:55.935000                     UTD
# 10   2016-12-09 00:12:04.913000                     UTD
# 11   2016-12-09 08:24:28.421000                     UTD
# 15   2016-12-16 21:21:48.701000                     UTD
# 18   2016-12-23 14:26:53.141000                     UTD
# 29   2016-12-23 15:36:57.066000                     UTD
# 31   2016-12-23 15:43:06.694000                     UTD
# 33   2016-12-23 15:55:30.592000                     UTD
# 46   2016-12-23 18:27:11.043000                     UTD
# 49   2016-12-23 18:58:46.630000                     UTD
# 52   2016-12-23 19:56:42.491000                     UTD
# 67   2016-12-23 23:31:09.523000                     UTD
# 68   2016-12-23 23:31:09.960000                     UTD
# ...

# %%
df.head()
# Out:
#                                     Timestamp  \
# 0  To add an entry to the sheet please go to:
# 1                  2016-12-07 19:43:51.909000
# 2                  2016-12-07 20:28:00.274000
# 3                  2016-12-07 20:40:01.732000
# 4                  2016-12-07 21:19:19.567000
#
#              Applied University Name  \
# 0         http://bit.ly/fall17MSform
# 1                                UTD
# 2                                UTD
# 3  Michigan technological University
# 4           Arizona State University
#
#                                     Applied Branch                 Decision  \
# 0  If you feel any entry is fake let me know at ->  srujanbarai75@gmail.com
# 1                                            MS CS                    Admit
# 2                                             Mech                    Admit
# 3                                    Data science                     Admit
# ...

# %%
df.drop('Timestamp', axis=1, inplace=True)

# %%
df.head()
# Out:
#              Applied University Name  \
# 0         http://bit.ly/fall17MSform
# 1                                UTD
# 2                                UTD
# 3  Michigan technological University
# 4           Arizona State University
#
#                                     Applied Branch                 Decision  \
# 0  If you feel any entry is fake let me know at ->  srujanbarai75@gmail.com
# 1                                            MS CS                    Admit
# 2                                             Mech                    Admit
# 3                                    Data science                     Admit
# 4                               Business Analytics                    Admit
#
#     Acads          UG University                GRE Total GRE Quant  \
# 0     NaN  Link to FALL 14 Sheet  Link to String 15 Sheet       NaN
# 1  7.6/10                     MU                      326       167
# 2  7.5/10       Anna University                       318       158
# ...

# %%
df.drop(df.index[0], inplace=True)

# %%
df.head()
# Out:
#              Applied University Name      Applied Branch Decision   Acads  \
# 1                                UTD               MS CS    Admit  7.6/10
# 2                                UTD                Mech    Admit  7.5/10
# 3  Michigan technological University       Data science     Admit  6.6/10
# 4           Arizona State University  Business Analytics    Admit    7.85
# 5      University of Texas Arlington              Civil     Admit    7.52
#
#        UG University GRE Total GRE Quant GRE Verbal             TOEFL IELTS  \
# 1                 MU       326       167        159  114(30,30,24,30)   NaN
# 2   Anna University        318       158        160  110(29:29:24:28)   NaN
# 3  GITAM University        303       154        149   97(26:25:20:26)   NaN
# 4                 MU       307       161        146                99   NaN
# 5   Kiit University        324       167        157               108   NaN
#
# ...

# %%
sample1=df[(df['Applied University Name']=='UTD') & (df['Decision']=='Admit')][['Applied University Name','Applied Branch','Acads','GRE Total']]

# %%
len(sample1)
# Out:
# 33

# %%
df[df['Your name (Optional)']=='Akilesh']
# Out:
# Empty DataFrame
# Columns: [Applied University Name, Applied Branch, Decision, Acads, UG University, GRE Total, GRE Quant, GRE Verbal, TOEFL, IELTS, Work Ex, UG Branch, Category (your assumption), Application Date, Decision Date, Your name (Optional), Your mail ID (Optional), Email Address, Paper Published , Outstanding achievements , Unnamed: 21]
# Index: []
#
# [0 rows x 21 columns]

# %%
gb_name=df.groupby('Applied University Name')

# %%
gb_name.count()
# Out:
#                                    Applied Branch  Decision  Acads  \
# Applied University Name
#  Brown University                               1         1      1
# -                                               1         1      1
# ASU                                            12        12     12
# ASu                                             1         1      1
# Arizona                                         1         1      1
# Arizona State University                       20        20     20
# Arizona State University                        4         4      4
# Arizona state university                        2         2      2
# Boston university                               1         1      1
# Bowling Green State Univeristy                  1         1      1
# Bradley                                         1         1      1
# CMU                                             2         2      2
# CSU EB                                          1         1      1
# ...

# %%
df['GRE Total'].apply(pd.to_numeric, errors='ignore')
# Out:
# 1      326
# 2      318
# 3      303
# 4      307
# 5      324
# 6      311
# 7      308
# 8      308
# 9      308
# 10     318
# 11     304
# 12     326
# 13     312
# 14     303
# 15     321
# 16     296
# 17     317
# 18     309
# 19     311
# 20     320
# 21     326
# 22     303
# 23     296
# 24     325
# 25     319
# 26     320
# 27     320
# 28     320
# 29     316
# 30     320
#       ...
# 457    300
# 458    300
# 459    328
# 460    324
# 461    323
# 462    315
# 463    308
# 464    320
# 465    322
# 466    325
# 467    331
# 468    303
# 469    305
# 470    304
# 471    304
# 472    304
# 473    316
# 474    324
# 475    312
# 476    300
# 477    300
# 478    330
# 479    330
# 480    330
# 481    330
# 482    314
# 483    313
# 484    319
# 485    319
# 486      -
# Name: GRE Total, Length: 486, dtype: object

# %%
df['GRE Total'] = df['GRE Total'].astype('int32')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-171-ef761220ec27> in <module>()
# ----> 1 df['GRE Total'] = df['GRE Total'].astype('int32')
#
# /anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
#    4003         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4004                                      **kwargs)
#    4005         return self._constructor(new_data).__finalize__(self)
#    4006
#
# ...

# %%
gre=df['GRE Total']

# %%
df['GRE Total']=pd.to_numeric(gre, errors='coerce')

# %%
df['GRE Total'].dtype
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# Applied University Name        object
# Applied Branch                 object
# Decision                       object
# Acads                          object
# UG University                  object
# GRE Total                     float64
# GRE Quant                      object
# GRE Verbal                     object
# TOEFL                          object
# IELTS                          object
# Work Ex                        object
# UG Branch                      object
# Category (your assumption)     object
# Application Date               object
# Decision Date                  object
# Your name (Optional)           object
# Your mail ID (Optional)        object
# Email Address                 float64
# Paper Published                object
# Outstanding achievements       object
# Unnamed: 21                   float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Applied University Name', 'Applied Branch', 'Decision', 'Acads',
#        'UG University', 'GRE Total', 'GRE Quant', 'GRE Verbal', 'TOEFL',
#        'IELTS', 'Work Ex', 'UG Branch', 'Category (your assumption)',
#        'Application Date', 'Decision Date', 'Your name (Optional)',
#        'Your mail ID (Optional)', 'Email Address', 'Paper Published ',
#        'Outstanding achievements ', 'Unnamed: 21'],
#       dtype='object')

# %%
df['GRE Quant']=pd.to_numeric(df['GRE Quant'], errors='coerce')

# %%
df['GRE Verbal']=pd.to_numeric(df['GRE Verbal'], errors='coerce')

# %%
df.dtypes
# Out:
# Applied University Name        object
# Applied Branch                 object
# Decision                       object
# Acads                          object
# UG University                  object
# GRE Total                     float64
# GRE Quant                     float64
# GRE Verbal                    float64
# TOEFL                          object
# IELTS                          object
# Work Ex                        object
# UG Branch                      object
# Category (your assumption)     object
# Application Date               object
# Decision Date                  object
# Your name (Optional)           object
# Your mail ID (Optional)        object
# Email Address                 float64
# Paper Published                object
# Outstanding achievements       object
# Unnamed: 21                   float64
# dtype: object

# %%
df.drop('Your name (Optional)', axis=1, inplace=True)

# %%
df.drop('Your mail ID (Optional)', axis=1, inplace=True)

# %%
df.drop('Email Address', axis=1, inplace=True)

# %%
df.drop('Unnamed: 21', axis=1, inplace=True)

# %%
df.dtypes
# Out:
# Applied University Name        object
# Applied Branch                 object
# Decision                       object
# Acads                          object
# UG University                  object
# GRE Total                     float64
# GRE Quant                     float64
# GRE Verbal                    float64
# TOEFL                          object
# IELTS                          object
# Work Ex                        object
# UG Branch                      object
# Category (your assumption)     object
# Application Date               object
# Decision Date                  object
# Paper Published                object
# Outstanding achievements       object
# dtype: object

# %%
df['TOEFL']=pd.to_numeric(df['TOEFL'], errors='coerce')

# %%
df['IELTS']=pd.to_numeric(df['IELTS'], errors='coerce')

# %%
df.dtypes
# Out:
# Applied University Name        object
# Applied Branch                 object
# Decision                       object
# Acads                          object
# UG University                  object
# GRE Total                     float64
# GRE Quant                     float64
# GRE Verbal                    float64
# TOEFL                         float64
# IELTS                         float64
# Work Ex                        object
# UG Branch                      object
# Category (your assumption)     object
# Application Date               object
# Decision Date                  object
# Paper Published                object
# Outstanding achievements       object
# dtype: object

# %%
df.head()
# Out:
#              Applied University Name      Applied Branch Decision   Acads  \
# 1                                UTD               MS CS    Admit  7.6/10
# 2                                UTD                Mech    Admit  7.5/10
# 3  Michigan technological University       Data science     Admit  6.6/10
# 4           Arizona State University  Business Analytics    Admit    7.85
# 5      University of Texas Arlington              Civil     Admit    7.52
#
#        UG University  GRE Total  GRE Quant  GRE Verbal  TOEFL  IELTS Work Ex  \
# 1                 MU      326.0      167.0       159.0    NaN    NaN       0
# 2   Anna University       318.0      158.0       160.0    NaN    NaN       0
# 3  GITAM University       303.0      154.0       149.0    NaN    NaN       0
# 4                 MU      307.0      161.0       146.0   99.0    NaN       0
# 5   Kiit University       324.0      167.0       157.0  108.0    NaN       0
#
# ...

# %%
df
# Out:
#                   Applied University Name  \
# 1                                     UTD
# 2                                     UTD
# 3       Michigan technological University
# 4                Arizona State University
# 5           University of Texas Arlington
# 6                                     UTD
# 7                  Wayne state university
# 8                  Santa Clara University
# 9                                     UTD
# 10                                    UTD
# 11                                    UTD
# 12                                    RIT
# 13                                   UNCC
# 14        Stevens institute of technology
# 15                                    UTD
# 16                           IIT Chicago
# 17                  Ohio State University
# 18                                    UTD
# 19            University of Texas Dallas
# 20                                    ASU
# 21     Michigan Technological University
# ...

# %%
gb_name=df.groupby('Applied University Name')

# %%
gb_name

# %%
gb_name.mean()
# Out:
#                                     GRE Total   GRE Quant  GRE Verbal  TOEFL  \
# Applied University Name
#  Brown University                  331.000000  168.000000  163.000000    NaN
# -                                         NaN         NaN         NaN    NaN
# ASU                                316.166667  165.000000  151.166667  102.8
# ASu                                309.000000  162.000000  147.000000    NaN
# Arizona                            318.000000  168.000000  150.000000  103.0
# Arizona State University           316.700000  163.900000  152.800000  104.0
# Arizona State University           318.000000  165.250000  152.750000   99.0
# Arizona state university           315.000000  163.000000  152.000000  108.0
# Boston university                  304.000000  159.000000  145.000000   91.0
# Bowling Green State Univeristy     295.000000  154.000000  142.000000    NaN
# Bradley                            298.000000  150.000000  148.000000   91.0
# ...

# %%
gb_name.describe()[['GRE Quant','GRE Verbal']]
# Out:
#                                   GRE Quant                               \
#                                       count        mean       std    min
# Applied University Name
#  Brown University                       1.0  168.000000       NaN  168.0
# -                                       0.0         NaN       NaN    NaN
# ASU                                    12.0  165.000000  2.132007  162.0
# ASu                                     1.0  162.000000       NaN  162.0
# Arizona                                 1.0  168.000000       NaN  168.0
# Arizona State University               20.0  163.900000  4.115439  153.0
# Arizona State University                4.0  165.250000  3.593976  160.0
# Arizona state university                2.0  163.000000  5.656854  159.0
# Boston university                       1.0  159.000000       NaN  159.0
# Bowling Green State Univeristy          1.0  154.000000       NaN  154.0
# ...

# %%
df['Applied University Name'].nunique()
# Out:
# 271

# %%
df['Applied University Name'].value_counts()
# Out:
# UTD                                     48
# Arizona State University                20
# UIC                                     13
# ASU                                     12
# UNCC                                     9
# Ohio State University                    9
# NCSU                                     8
# SUNY Buffalo                             7
# Santa Clara University                   6
# North Carolina State University          5
# UT Austin                                5
# University of Pennsylvania               5
# University of Southern California        5
# Michigan Technological University        5
# Georgia Tech                             4
# RIT                                      4
# Arizona State University                 4
# NEU                                      3
# UT Arlington                             3
# University of South Florida              3
# Stevens Institute of Technology          3
# Northeastern University                  3
# ...

# %%
df.columns
# Out:
# Index(['Applied University Name', 'Applied Branch', 'Decision', 'Acads',
#        'UG University', 'GRE Total', 'GRE Quant', 'GRE Verbal', 'TOEFL',
#        'IELTS', 'Work Ex', 'UG Branch', 'Category (your assumption)',
#        'Application Date', 'Decision Date', 'Paper Published ',
#        'Outstanding achievements '],
#       dtype='object')

# %%
df[df['Applied University Name']=='NCSU'][['Applied University Name','Acads','GRE Total','Applied Branch','Decision']]
# Out:
#     Applied University Name                      Acads  GRE Total  \
# 63                     NCSU                    8.26/10      315.0
# 136                    NCSU                       7.67      324.0
# 168                    NCSU                    8.43/10      313.0
# 231                    NCSU                       7.87      310.0
# 275                    NCSU                      86.74      320.0
# 369                    NCSU                       8.55      323.0
# 377                    NCSU  8.36(B.E.), 8.52(Diploma)      315.0
# 425                    NCSU                       7.52      324.0
#
#     Applied Branch Decision
# 63              IE    Admit
# 136     Industrial   Reject
# 168             IE    Admit
# 231           EPSE    Admit
# 275             EE    Admit
# 369             IE    Admit
# 377     Mechanical    Admit
# 425         CIVIL     Admit

# %%
df['Applied University Name'].value_counts()
# Out:
# UTD                                     48
# Arizona State University                20
# UIC                                     13
# ASU                                     12
# UNCC                                     9
# Ohio State University                    9
# NCSU                                     8
# SUNY Buffalo                             7
# Santa Clara University                   6
# North Carolina State University          5
# UT Austin                                5
# University of Pennsylvania               5
# University of Southern California        5
# Michigan Technological University        5
# Georgia Tech                             4
# RIT                                      4
# Arizona State University                 4
# NEU                                      3
# UT Arlington                             3
# University of South Florida              3
# Stevens Institute of Technology          3
# Northeastern University                  3
# ...

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
